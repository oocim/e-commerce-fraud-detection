# %% [markdown]
# # Fraud Detection — Fine-tune ResNet-50 on Product Images (Colab)
#
# This notebook:
# 1. Uploads `image_dataset.csv` (contains `product_id`, `fraud_label`, `image_url`)
# 2. Downloads product images from URLs
# 3. Fine-tunes a pretrained **ResNet-50** for binary fraud classification
# 4. Uses heavy image augmentation + label smoothing + early stopping
# 5. Reports evaluation metrics on a stratified test split
#
# **Make sure to select GPU runtime:** Runtime → Change runtime type → T4 GPU

# %%
# Install dependencies (Colab-compatible — use Colab's pre-installed torch/pandas/numpy)
# !pip -q install torchvision scikit-learn Pillow requests tqdm

# %%
import os
import io
import warnings
import requests
import numpy as np
import pandas as pd
from pathlib import Path
from PIL import Image
from tqdm.auto import tqdm
from concurrent.futures import ThreadPoolExecutor, as_completed

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    roc_auc_score,
    f1_score,
    accuracy_score,
    average_precision_score,
)

warnings.filterwarnings('ignore')

try:
    from google.colab import files
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Device: {device}')
if device.type == 'cuda':
    print(f'GPU: {torch.cuda.get_device_name(0)}')

# %%
# Config
IMG_SIZE = 224
BATCH_SIZE = 32
EPOCHS = 20           # increased — early stopping (patience=4) will halt at optimal epoch
LR = 1e-4
LABEL_SMOOTHING = 0.05  # prevents overconfident predictions
EARLY_STOP_PATIENCE = 4  # stop if val F1 doesn't improve for 4 epochs
SEED = 42
N_FOLDS = 5           # stratified k-fold cross-validation
NUM_WORKERS = 2
IMAGE_DIR = Path('./downloaded_images')
MODEL_SAVE_PATH = Path('./resnet_fraud_model')

# Focal loss config (addresses class imbalance — image model got F1=0.00)
# The image model collapsed to "always predict legit" because 95.7% of
# samples are legit and standard CE rewards that degenerate solution.
FOCAL_ALPHA = 0.80   # higher than text (0.75) because image has less signal
FOCAL_GAMMA = 2.0    # focusing parameter

IMAGE_DIR.mkdir(exist_ok=True)
MODEL_SAVE_PATH.mkdir(exist_ok=True)


torch.manual_seed(SEED)
np.random.seed(SEED)

# %%
# Upload image_dataset.csv
if IN_COLAB:
    print('Upload image_dataset.csv ...')
    uploaded = files.upload()
    if 'image_dataset.csv' not in uploaded:
        raise ValueError(f'Expected image_dataset.csv. Uploaded: {list(uploaded.keys())}')
    df = pd.read_csv(io.BytesIO(uploaded['image_dataset.csv']))
else:
    df = pd.read_csv('processed_data/image_dataset.csv')

print(f'Dataset shape: {df.shape}')
print(f'Fraud distribution:\n{df["fraud_label"].value_counts()}\n')

# %%
# Download images from URLs (parallel, with retry)
HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
}

def download_image(row):
    """Download a single image. Returns (product_id, success)."""
    pid = str(row['product_id']).zfill(6)
    url = row['image_url']
    save_path = IMAGE_DIR / f'{pid}.jpg'
    if save_path.exists():
        return pid, True
    try:
        resp = requests.get(url, headers=HEADERS, timeout=15)
        resp.raise_for_status()
        img = Image.open(io.BytesIO(resp.content)).convert('RGB')
        img.save(save_path, 'JPEG')
        return pid, True
    except Exception:
        return pid, False

print(f'Downloading {len(df)} images (skipping already downloaded) ...')
results = []
with ThreadPoolExecutor(max_workers=16) as executor:
    futures = {executor.submit(download_image, row): row for _, row in df.iterrows()}
    for future in tqdm(as_completed(futures), total=len(futures)):
        results.append(future.result())

success_ids = {pid for pid, ok in results if ok}
failed_ids  = {pid for pid, ok in results if not ok}
print(f'\nDownloaded: {len(success_ids)} | Failed: {len(failed_ids)}')

# Keep only rows with successfully downloaded images
df['pid_str'] = df['product_id'].apply(lambda x: str(x).zfill(6))
df = df[df['pid_str'].isin(success_ids)].reset_index(drop=True)
print(f'Usable samples: {len(df)}')
print(f'Fraud distribution after filtering:\n{df["fraud_label"].value_counts()}')

# %%
# Transforms & Dataset class
# Heavy augmentation for training — e-commerce product images vary in
# framing, zoom, lighting, backgrounds, and quality. These transforms
# force the model to learn fraud-relevant visual patterns (e.g. stock
# photos, watermarks, low quality) rather than memorizing exact images.
train_transform = transforms.Compose([
    transforms.Resize((int(IMG_SIZE * 1.15), int(IMG_SIZE * 1.15))),
    transforms.RandomResizedCrop(IMG_SIZE, scale=(0.7, 1.0), ratio=(0.85, 1.15)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.05),
    transforms.RandomRotation(20),
    transforms.RandomAffine(
        degrees=0,
        translate=(0.1, 0.1),
        scale=(0.9, 1.1),
        shear=10,
    ),
    transforms.RandomPerspective(distortion_scale=0.15, p=0.3),
    transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.2, hue=0.05),
    transforms.RandomGrayscale(p=0.05),
    transforms.GaussianBlur(kernel_size=3, sigma=(0.1, 1.5)),
    transforms.RandomAutocontrast(p=0.2),
    transforms.RandomEqualize(p=0.1),
    transforms.ToTensor(),
    transforms.RandomErasing(p=0.15, scale=(0.02, 0.15)),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

test_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])


class FraudImageDataset(Dataset):
    def __init__(self, dataframe, img_dir, transform):
        self.df = dataframe
        self.img_dir = img_dir
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        pid = str(row['product_id']).zfill(6)
        img_path = self.img_dir / f'{pid}.jpg'
        image = Image.open(img_path).convert('RGB')
        image = self.transform(image)
        label = torch.tensor(row['fraud_label'], dtype=torch.long)
        return image, label

print(f'Image transforms defined')
print(f'Training augmentations: 11 transforms + RandomErasing')
print(f'Test: Resize + Normalize only')

# %%
# Focal Loss + Model builder + Stratified sampler

class FocalLoss(nn.Module):
    """
    Focal Loss for imbalanced classification (Lin et al., 2017).

    With 4.3% fraud in the image dataset, standard CrossEntropy causes the
    model to predict ALL samples as legit (F1=0.0). Focal loss fixes this:
      - alpha: up-weights fraud class so it contributes more to the loss
      - gamma: down-weights easy/confident legit predictions so gradient
        focuses on hard fraud samples the model struggles with
    """
    def __init__(self, alpha=0.80, gamma=2.0, label_smoothing=0.0):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.label_smoothing = label_smoothing

    def forward(self, logits, targets):
        n_classes = logits.size(-1)
        if self.label_smoothing > 0:
            with torch.no_grad():
                smooth_targets = torch.zeros_like(logits)
                smooth_targets.fill_(self.label_smoothing / (n_classes - 1))
                smooth_targets.scatter_(1, targets.unsqueeze(1), 1.0 - self.label_smoothing)
        else:
            smooth_targets = torch.zeros_like(logits)
            smooth_targets.scatter_(1, targets.unsqueeze(1), 1.0)

        log_probs = torch.log_softmax(logits, dim=-1)
        probs = torch.exp(log_probs)

        alpha_weight = torch.where(targets == 1, self.alpha, 1.0 - self.alpha)
        p_t = probs.gather(1, targets.unsqueeze(1)).squeeze(1)
        focal_weight = (1.0 - p_t) ** self.gamma

        loss = -(smooth_targets * log_probs).sum(dim=-1)
        loss = alpha_weight * focal_weight * loss
        return loss.mean()


def build_model():
    """Create a fresh ResNet-50 with custom head, frozen early layers."""
    m = models.resnet50(weights=models.ResNet50_Weights.IMAGENET1K_V2)

    # Freeze early layers, fine-tune layer4 + fc
    for param in m.parameters():
        param.requires_grad = False
    for param in m.layer4.parameters():
        param.requires_grad = True

    # Replace classifier
    in_features = m.fc.in_features
    m.fc = nn.Sequential(
        nn.Dropout(0.3),
        nn.Linear(in_features, 256),
        nn.ReLU(),
        nn.Dropout(0.2),
        nn.Linear(256, 2),
    )
    return m.to(device)


def make_stratified_sampler(labels):
    """
    Create a WeightedRandomSampler that ensures every batch contains fraud examples.

    Problem: With 4.3% fraud and batch_size=32, many batches get ZERO fraud
    samples purely by chance. The model never trains on fraud in those batches.

    Solution: Oversample fraud in each epoch so the model sees fraud examples
    regularly. This doesn't change the model weights — just the sampling
    frequency during training. Each epoch still sees len(dataset) samples.
    """
    class_counts = np.bincount(labels)
    # Weight = 1/class_frequency → fraud gets ~22x higher sampling probability
    class_weights = 1.0 / class_counts
    sample_weights = class_weights[labels]
    sampler = torch.utils.data.WeightedRandomSampler(
        weights=sample_weights,
        num_samples=len(labels),
        replacement=True,
    )
    return sampler


# NOTE: Using Focal Loss (not CrossEntropy) + stratified batch sampling.
# No class_weight in the model — focal loss handles imbalance instead.
print(f'Model builder ready: ResNet-50 (IMAGENET1K_V2), fine-tune layer4 + FC')
print(f'Loss: FocalLoss(alpha={FOCAL_ALPHA}, gamma={FOCAL_GAMMA}, label_smoothing={LABEL_SMOOTHING})')
print(f'Sampling: WeightedRandomSampler (oversamples fraud in each batch)')
print(f'Optimizer: AdamW(lr={LR}, wd=1e-4), CosineAnnealing scheduler')

# %%
# ═══════════════════════════════════════════════════════════════════
#  5-FOLD STRATIFIED CROSS-VALIDATION
# ═══════════════════════════════════════════════════════════════════
# Each fold:
#   1. Split data into train/val (stratified by fraud_label)
#   2. Create DataLoaders with stratified sampling + augmentation
#   3. Train with Focal Loss + early stopping on val F1
#   4. Collect out-of-fold predictions
# ═══════════════════════════════════════════════════════════════════

skf = StratifiedKFold(n_splits=N_FOLDS, shuffle=True, random_state=SEED)

fold_metrics = []
all_val_pids = []
all_val_labels = []
all_val_probs = []
all_val_preds = []

for fold_idx, (train_indices, val_indices) in enumerate(skf.split(df, df['fraud_label']), 1):
    print(f'\n{"="*60}')
    print(f'  FOLD {fold_idx}/{N_FOLDS}')
    print(f'{"="*60}')

    fold_train_df = df.iloc[train_indices].reset_index(drop=True)
    fold_val_df   = df.iloc[val_indices].reset_index(drop=True)

    n_train_fraud = fold_train_df['fraud_label'].sum()
    n_val_fraud   = fold_val_df['fraud_label'].sum()
    print(f'Train: {len(fold_train_df)} ({n_train_fraud} fraud, {100*n_train_fraud/len(fold_train_df):.1f}%)')
    print(f'Val:   {len(fold_val_df)} ({n_val_fraud} fraud, {100*n_val_fraud/len(fold_val_df):.1f}%)')

    # Create datasets & loaders with stratified sampling
    train_dataset = FraudImageDataset(fold_train_df, IMAGE_DIR, train_transform)
    val_dataset   = FraudImageDataset(fold_val_df,   IMAGE_DIR, test_transform)

    # Stratified sampler ensures every batch contains fraud examples
    train_labels = fold_train_df['fraud_label'].values
    train_sampler = make_stratified_sampler(train_labels)

    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE,
                              sampler=train_sampler,  # replaces shuffle=True
                              num_workers=NUM_WORKERS, pin_memory=True)
    val_loader   = DataLoader(val_dataset,  batch_size=BATCH_SIZE, shuffle=False,
                              num_workers=NUM_WORKERS, pin_memory=True)

    # Fresh model, optimizer, scheduler, loss for each fold
    fold_model = build_model()
    criterion = FocalLoss(alpha=FOCAL_ALPHA, gamma=FOCAL_GAMMA,
                          label_smoothing=LABEL_SMOOTHING)
    optimizer = torch.optim.AdamW(
        filter(lambda p: p.requires_grad, fold_model.parameters()),
        lr=LR, weight_decay=1e-4,
    )
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS)

    if fold_idx == 1:
        trainable = sum(p.numel() for p in fold_model.parameters() if p.requires_grad)
        total     = sum(p.numel() for p in fold_model.parameters())
        print(f'Trainable params: {trainable:,} / {total:,} ({100*trainable/total:.1f}%)')

    # --- Training loop with early stopping ---
    best_f1 = -1.0
    patience_counter = 0
    best_state = {k: v.cpu().clone() for k, v in fold_model.state_dict().items()}

    for epoch in range(1, EPOCHS + 1):
        # Train
        fold_model.train()
        running_loss = 0.0
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = fold_model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * images.size(0)
        train_loss = running_loss / len(train_dataset)

        # Evaluate
        fold_model.eval()
        val_loss = 0.0
        ep_preds, ep_labels, ep_probs = [], [], []
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = fold_model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * images.size(0)
                probs = torch.softmax(outputs, dim=1)[:, 1]
                preds = outputs.argmax(dim=1)
                ep_preds.extend(preds.cpu().numpy())
                ep_labels.extend(labels.cpu().numpy())
                ep_probs.extend(probs.cpu().numpy())

        val_loss = val_loss / len(val_dataset)
        val_acc = accuracy_score(ep_labels, ep_preds)
        val_f1  = f1_score(ep_labels, ep_preds)

        scheduler.step()

        marker = ''
        if val_f1 > best_f1:
            best_f1 = val_f1
            patience_counter = 0
            best_state = {k: v.cpu().clone() for k, v in fold_model.state_dict().items()}
            marker = ' ← best'
        else:
            patience_counter += 1
            if patience_counter >= EARLY_STOP_PATIENCE:
                print(f'  Epoch {epoch}/{EPOCHS}  train_loss={train_loss:.4f}  '
                      f'val_loss={val_loss:.4f}  val_f1={val_f1:.4f} ← early stop')
                break

        print(f'  Epoch {epoch}/{EPOCHS}  train_loss={train_loss:.4f}  '
              f'val_loss={val_loss:.4f}  val_f1={val_f1:.4f}{marker}')

    # Load best model weights for this fold and get final predictions
    fold_model.load_state_dict(best_state)
    fold_model.eval()
    fold_preds, fold_labels, fold_probs = [], [], []
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = fold_model(images)
            probs = torch.softmax(outputs, dim=1)[:, 1]
            preds = outputs.argmax(dim=1)
            fold_preds.extend(preds.cpu().numpy())
            fold_labels.extend(labels.cpu().numpy())
            fold_probs.extend(probs.cpu().numpy())

    fold_preds  = np.array(fold_preds)
    fold_labels = np.array(fold_labels)
    fold_probs  = np.array(fold_probs)

    fold_acc = accuracy_score(fold_labels, fold_preds)
    fold_f1  = f1_score(fold_labels, fold_preds)
    fold_roc = roc_auc_score(fold_labels, fold_probs)
    fold_ap  = average_precision_score(fold_labels, fold_probs)

    fold_metrics.append({
        'fold': fold_idx,
        'accuracy': fold_acc,
        'f1': fold_f1,
        'roc_auc': fold_roc,
        'avg_precision': fold_ap,
        'best_epoch': epoch - patience_counter,
    })

    # Collect out-of-fold predictions
    all_val_pids.extend(fold_val_df['product_id'].values)
    all_val_labels.extend(fold_labels)
    all_val_probs.extend(fold_probs)
    all_val_preds.extend(fold_preds)

    print(f'\n  Fold {fold_idx} results (best epoch {epoch - patience_counter}):')
    print(f'    Accuracy: {fold_acc:.4f}  F1: {fold_f1:.4f}  ROC-AUC: {fold_roc:.4f}  AP: {fold_ap:.4f}')

    # Clean up GPU memory
    del fold_model, optimizer, scheduler, best_state
    torch.cuda.empty_cache() if device.type == 'cuda' else None

print(f'\n{"="*60}')
print(f'  ALL FOLDS COMPLETE')
print(f'{"="*60}')

# %%
# ═══════════════════════════════════════════════════════════════════
#  AGGREGATED CROSS-VALIDATION RESULTS
# ═══════════════════════════════════════════════════════════════════

metrics_df = pd.DataFrame(fold_metrics)
print('Per-fold metrics:')
print(metrics_df.to_string(index=False, float_format='{:.4f}'.format))

print(f'\n{"="*60}')
print(f'  {N_FOLDS}-FOLD CV SUMMARY (mean ± std)')
print(f'{"="*60}')
for metric in ['accuracy', 'f1', 'roc_auc', 'avg_precision']:
    mean_val = metrics_df[metric].mean()
    std_val  = metrics_df[metric].std()
    print(f'{metric:20s}: {mean_val:.4f} ± {std_val:.4f}')

# Aggregated predictions (every sample validated exactly once)
y_true_all = np.array(all_val_labels)
y_pred_all = np.array(all_val_preds)
y_prob_all = np.array(all_val_probs)

print(f'\nAggregated results (all {len(y_true_all)} samples):')
print(f'  Accuracy: {accuracy_score(y_true_all, y_pred_all):.4f}')
print(f'  F1:       {f1_score(y_true_all, y_pred_all):.4f}')
print(f'  ROC-AUC:  {roc_auc_score(y_true_all, y_prob_all):.4f}')
print(f'  AP:       {average_precision_score(y_true_all, y_prob_all):.4f}')

print(f'\nClassification Report (aggregated):')
print(classification_report(y_true_all, y_pred_all, target_names=['Not Fraud', 'Fraud']))
print('Confusion Matrix (aggregated):')
print(confusion_matrix(y_true_all, y_pred_all))

# %%
# ═══════════════════════════════════════════════════════════════════
#  TRAIN FINAL MODEL ON ALL DATA (for deployment)
# ═══════════════════════════════════════════════════════════════════
# Use median best epoch from CV to set training duration.

avg_best_epoch = int(np.median([m['best_epoch'] for m in fold_metrics]))
final_epochs = max(3, avg_best_epoch)  # at least 3 epochs
print(f'Training final model on ALL {len(df)} samples for {final_epochs} epochs ...\n')

# Full dataset with augmentation + stratified sampling
full_dataset = FraudImageDataset(df, IMAGE_DIR, train_transform)
full_sampler = make_stratified_sampler(df['fraud_label'].values)
full_loader  = DataLoader(full_dataset, batch_size=BATCH_SIZE,
                           sampler=full_sampler,
                           num_workers=NUM_WORKERS, pin_memory=True)

final_model = build_model()
criterion = FocalLoss(alpha=FOCAL_ALPHA, gamma=FOCAL_GAMMA,
                      label_smoothing=LABEL_SMOOTHING)
optimizer = torch.optim.AdamW(
    filter(lambda p: p.requires_grad, final_model.parameters()),
    lr=LR, weight_decay=1e-4,
)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=final_epochs)

for epoch in range(1, final_epochs + 1):
    final_model.train()
    running_loss = 0.0
    for images, labels in full_loader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = final_model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * images.size(0)
    train_loss = running_loss / len(full_dataset)
    scheduler.step()
    print(f'  Epoch {epoch}/{final_epochs}  train_loss={train_loss:.4f}')

torch.save(final_model.state_dict(), MODEL_SAVE_PATH / 'best_resnet50.pth')
print(f'\nFinal model saved to: {(MODEL_SAVE_PATH / "best_resnet50.pth").resolve()}')

# %%
# Export cross-validated predictions for ensemble
image_preds_df = pd.DataFrame({
    'product_id': all_val_pids,
    'fraud_label': y_true_all,
    'image_fraud_proba': y_prob_all,
    'image_pred': y_pred_all,
})
image_preds_df.to_csv('image_test_predictions.csv', index=False)
print(f'Saved image_test_predictions.csv  ({len(image_preds_df)} rows — all samples, cross-validated)')
print(image_preds_df.head())

# Download for local ensemble
if IN_COLAB:
    files.download('image_test_predictions.csv')

# %%
# Final model saved — download in Colab
print(f'Best model saved to: {(MODEL_SAVE_PATH / "best_resnet50.pth").resolve()}')
if IN_COLAB:
    files.download(str(MODEL_SAVE_PATH / 'best_resnet50.pth'))
