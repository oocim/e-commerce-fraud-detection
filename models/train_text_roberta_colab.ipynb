# %% [markdown]
# # Fraud Detection — Hybrid TF-IDF + RoBERTa (Colab)
#
# This notebook uploads `text_dataset.csv`, performs a stratified train/test split, extracts **TF-IDF features** and **RoBERTa contextual embeddings**, fuses them in a hybrid model, and reports evaluation metrics.
#
# **Architecture:** Text → TF-IDF (5000-d → 256-d projection) + RoBERTa [CLS] (768-d) → Concatenate (1024-d) → Classifier → Fraud / Not Fraud

# %%
# Install dependencies (Colab-compatible — use Colab's pre-installed pandas/numpy)
# !pip -q install transformers scikit-learn scipy joblib imbalanced-learn

# %%
import os
import io
import random
import warnings
import joblib
import numpy as np
import pandas as pd
from pathlib import Path

import torch
import torch.nn as nn
from torch.utils.data import Dataset

from sklearn.model_selection import StratifiedKFold
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    roc_auc_score,
    f1_score,
    accuracy_score,
    average_precision_score,
)
from sklearn.neighbors import NearestNeighbors
from imblearn.over_sampling import SMOTE

from transformers import (
    RobertaTokenizer,
    RobertaModel,
    Trainer,
    TrainingArguments,
    EarlyStoppingCallback,
)

warnings.filterwarnings("ignore")

try:
    from google.colab import files
    IN_COLAB = True
except ImportError:
    IN_COLAB = False

# %%
# Config
OUTPUT_DIR = Path('./roberta_fraud_model')
MODEL_NAME = 'roberta-base'
MAX_LEN = 256
BATCH_SIZE = 8
GRAD_ACCUM = 4
EPOCHS = 10          # increased — early stopping (patience=2) will halt at optimal epoch
LR = 2e-5            # restored — 1e-5 was too slow
DROPOUT = 0.3        # restored — 0.4 was too aggressive with layer freezing
LABEL_SMOOTHING = 0.05  # reduced from 0.1 — less target softening
SEED = 42
SYNTH_CAP = 300      # use all 300 template-generated synthetic fraud rows
N_FOLDS = 5          # stratified k-fold cross-validation

# Focal loss config (addresses class imbalance without class_weight)
# Standard CE treats all samples equally; with 95.7% legit, the model learns
# to always predict "legit". Focal loss down-weights confident/easy predictions
# so the gradient focuses on hard fraud samples the model struggles with.
FOCAL_ALPHA = 0.75   # weight for fraud class (>0.5 = emphasize minority)
FOCAL_GAMMA = 2.0    # focusing parameter (higher = more focus on hard examples)

# SMOTE config (oversamples fraud in TF-IDF feature space)
# After TF-IDF vectorization, SMOTE interpolates between real fraud vectors
# to synthesize new fraud samples. For each SMOTE sample, the nearest real
# fraud listing's text is used for RoBERTa (word dropout/swap add variation).
SMOTE_ENABLED = True
SMOTE_RATIO = 0.3          # target fraud ratio (0.3 = ~30% of majority count)
SMOTE_K_NEIGHBORS = 5      # neighbors for interpolation

# Text augmentation config (prevents RoBERTa from memorizing exact phrases)
WORD_DROPOUT_PROB = 0.15   # randomly replace 15% of tokens with <pad>
WORD_SWAP_PROB = 0.10      # swap adjacent token pairs with 10% probability

# TF-IDF config
TFIDF_MAX_FEATURES = 2000    # reduced from 5000 — fewer features = less overfitting
TFIDF_NGRAM_RANGE = (1, 2)   # unigrams + bigrams

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')
if device.type == 'cuda':
    print(f'GPU: {torch.cuda.get_device_name(0)}')

print('\nNext cell will ask you to upload text_dataset.csv')

# %%
# Upload and load text_dataset.csv + synthetic_text_dataset.csv
if IN_COLAB:
    print('Upload text_dataset.csv and synthetic_text_dataset.csv ...')
    uploaded = files.upload()
    if 'text_dataset.csv' not in uploaded:
        raise ValueError(f'Expected text_dataset.csv. Uploaded: {list(uploaded.keys())}')
    df = pd.read_csv(io.BytesIO(uploaded['text_dataset.csv']))
    if 'synthetic_text_dataset.csv' in uploaded:
        synth_df = pd.read_csv(io.BytesIO(uploaded['synthetic_text_dataset.csv']))
    else:
        raise ValueError('Also upload synthetic_text_dataset.csv')
else:
    df = pd.read_csv('processed_data/text_dataset.csv')
    synth_df = pd.read_csv('processed_data/synthetic_text_dataset.csv')

print(f'Original dataset: {df.shape}  |  Synthetic (fraud): {synth_df.shape}')
print(f'Original fraud dist:\n{df["fraud_label"].value_counts()}')

# Cap synthetic data to prevent overfitting
# The full 500 synthetic rows (all fraud) push fraud to 20.7%, which was
# too aggressive. Capping at SYNTH_CAP gives a more balanced boost.
if len(synth_df) > SYNTH_CAP:
    synth_df = synth_df.sample(n=SYNTH_CAP, random_state=SEED)
    print(f'\nCapped synthetic data to {SYNTH_CAP} rows (from {len(synth_df)})')

# Combine original + capped synthetic
df = pd.concat([df, synth_df], ignore_index=True)
n_total = len(df)
n_fraud = df['fraud_label'].sum()
print(f'\nCombined dataset: {df.shape}')
print(f'Combined fraud dist:\n{df["fraud_label"].value_counts()}')
print(f'Fraud ratio: {100*n_fraud/n_total:.1f}%\n')

text_cols = ['title_cleaned', 'description_cleaned', 'review1_cleaned', 'review2_cleaned']
for col in text_cols:
    df[col] = df[col].fillna('')

df['text'] = (
    'Title: ' + df['title_cleaned']
    + ' Description: ' + df['description_cleaned']
    + ' Review1: ' + df['review1_cleaned']
    + ' Review2: ' + df['review2_cleaned']
)

# %%
# Separate real and synthetic data for proper k-fold handling
# Synthetic data always goes in training, never in validation — prevents
# the model from being evaluated on data it was designed to memorize.
real_mask = df['product_id'] < 40000  # synthetic IDs start at 40000
real_df = df[real_mask].reset_index(drop=True)
synth_df_combined = df[~real_mask].reset_index(drop=True)

print(f'Real data:      {len(real_df)} rows ({real_df["fraud_label"].sum()} fraud)')
print(f'Synthetic data: {len(synth_df_combined)} rows ({synth_df_combined["fraud_label"].sum()} fraud)')
print(f'Synthetic data will be added to EVERY training fold (never in validation)')
print(f'\nStarting {N_FOLDS}-fold stratified cross-validation ...')

# %%
# Tokenizer & augmentation (shared across folds)
tokenizer = RobertaTokenizer.from_pretrained(MODEL_NAME)

def augment_tokens(input_ids, attention_mask, pad_token_id, dropout_prob, swap_prob):
    """
    Token-level text augmentation applied during training.
    Prevents RoBERTa from memorizing exact phrases by randomly:
      1. Dropping words (replacing with <pad>) — forces model to use context
      2. Swapping adjacent words — breaks exact sequence patterns
    Only modifies real tokens (not special tokens like <s>, </s>, <pad>).
    """
    ids = input_ids.clone()
    mask = attention_mask.clone()
    seq_len = ids.size(0)

    # Find non-special token positions (skip <s>=0, </s>=2, <pad>=1)
    special_ids = {0, 1, 2}  # RoBERTa special token IDs
    real_positions = [i for i in range(seq_len)
                      if ids[i].item() not in special_ids and mask[i].item() == 1]

    if len(real_positions) < 3:
        return ids, mask  # too short to augment

    # 1. Word dropout: replace random tokens with <pad>
    for pos in real_positions:
        if random.random() < dropout_prob:
            ids[pos] = pad_token_id

    # 2. Word swap: swap adjacent token pairs
    for i in range(len(real_positions) - 1):
        if random.random() < swap_prob:
            p1, p2 = real_positions[i], real_positions[i + 1]
            ids[p1], ids[p2] = ids[p2].clone(), ids[p1].clone()

    return ids, mask


class FraudTextDataset(Dataset):
    """
    Dataset that returns RoBERTa tokens + TF-IDF features.
    When training=True, applies random token-level augmentation each
    time a sample is accessed, so the model sees different variations
    every epoch — effectively multiplying data diversity.
    """
    def __init__(self, texts, labels, tfidf_matrix, training=False):
        self.encodings = tokenizer(
            texts,
            truncation=True,
            padding='max_length',
            max_length=MAX_LEN,
            return_tensors='pt',
        )
        self.labels = torch.tensor(labels, dtype=torch.long)
        self.tfidf  = torch.tensor(tfidf_matrix, dtype=torch.float32)
        self.training = training
        self.pad_token_id = tokenizer.pad_token_id

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        input_ids = self.encodings['input_ids'][idx]
        attention_mask = self.encodings['attention_mask'][idx]

        # Apply text augmentation during training only
        if self.training:
            input_ids, attention_mask = augment_tokens(
                input_ids, attention_mask, self.pad_token_id,
                WORD_DROPOUT_PROB, WORD_SWAP_PROB,
            )

        return {
            'input_ids':      input_ids,
            'attention_mask': attention_mask,
            'tfidf_features': self.tfidf[idx],
            'labels':         self.labels[idx],
        }

print(f'Tokenizer loaded: {MODEL_NAME}')
print(f'Text augmentation: word_dropout={WORD_DROPOUT_PROB}, word_swap={WORD_SWAP_PROB} (training only)')

# %%
# Focal Loss + Hybrid model definition: RoBERTa [CLS] + TF-IDF → classifier

class FocalLoss(nn.Module):
    """
    Focal Loss for imbalanced classification (Lin et al., 2017).

    Standard CrossEntropy treats all samples equally. With 95.7% legit data,
    the model learns to always predict "legit" because it's right 95.7% of
    the time. Focal Loss fixes this by:
      1. alpha: up-weights the minority (fraud) class
      2. gamma: down-weights confident/easy predictions (e.g., obvious legit)
         so gradient focuses on hard examples the model gets wrong

    FL(p_t) = -alpha_t * (1 - p_t)^gamma * log(p_t)
    """
    def __init__(self, alpha=0.75, gamma=2.0, label_smoothing=0.0):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.label_smoothing = label_smoothing

    def forward(self, logits, targets):
        # Apply label smoothing
        n_classes = logits.size(-1)
        if self.label_smoothing > 0:
            with torch.no_grad():
                smooth_targets = torch.zeros_like(logits)
                smooth_targets.fill_(self.label_smoothing / (n_classes - 1))
                smooth_targets.scatter_(1, targets.unsqueeze(1), 1.0 - self.label_smoothing)
        else:
            smooth_targets = torch.zeros_like(logits)
            smooth_targets.scatter_(1, targets.unsqueeze(1), 1.0)

        log_probs = torch.log_softmax(logits, dim=-1)
        probs = torch.exp(log_probs)

        # Per-class alpha weights: [1-alpha for class 0, alpha for class 1]
        alpha_weight = torch.where(targets == 1, self.alpha, 1.0 - self.alpha)

        # Focal modulation: (1 - p_t)^gamma
        p_t = probs.gather(1, targets.unsqueeze(1)).squeeze(1)
        focal_weight = (1.0 - p_t) ** self.gamma

        # Weighted cross-entropy with focal modulation
        loss = -(smooth_targets * log_probs).sum(dim=-1)
        loss = alpha_weight * focal_weight * loss
        return loss.mean()


class RoBERTaTfidfFraudModel(nn.Module):
    """
    Concatenates RoBERTa's [CLS] embedding (768-d) with TF-IDF features
    before a shared classification head.

    Anti-overfitting measures:
      - Freeze all RoBERTa layers except the last 4 encoder blocks + pooler
      - Dropout (0.3) in projection and classifier
      - Focal loss (alpha=0.75, gamma=2.0) for class imbalance
    Note: The main overconfidence fix is NO class_weight + capped synthetic data.
    """
    def __init__(self, model_name, tfidf_dim, num_labels=2, dropout=DROPOUT):
        super().__init__()
        self.roberta = RobertaModel.from_pretrained(model_name)
        roberta_dim = self.roberta.config.hidden_size  # 768

        # Freeze all RoBERTa except last 4 encoder layers + pooler
        for name, param in self.roberta.named_parameters():
            param.requires_grad = False
        for layer in self.roberta.encoder.layer[-4:]:
            for param in layer.parameters():
                param.requires_grad = True
        if hasattr(self.roberta, 'pooler') and self.roberta.pooler is not None:
            for param in self.roberta.pooler.parameters():
                param.requires_grad = True

        self.tfidf_proj = nn.Sequential(
            nn.Linear(tfidf_dim, 256),
            nn.ReLU(),
            nn.Dropout(dropout),
        )

        fused_dim = roberta_dim + 256  # 768 + 256 = 1024

        self.classifier = nn.Sequential(
            nn.Linear(fused_dim, 256),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(256, num_labels),
        )

        # Focal loss instead of CrossEntropy — critical for imbalanced data
        self.loss_fn = FocalLoss(
            alpha=FOCAL_ALPHA,
            gamma=FOCAL_GAMMA,
            label_smoothing=LABEL_SMOOTHING,
        )

    def forward(self, input_ids, attention_mask, tfidf_features, labels=None):
        roberta_out = self.roberta(input_ids=input_ids, attention_mask=attention_mask)
        cls_emb = roberta_out.last_hidden_state[:, 0, :]  # [batch, 768]
        tfidf_emb = self.tfidf_proj(tfidf_features)        # [batch, 256]
        fused = torch.cat([cls_emb, tfidf_emb], dim=-1)    # [batch, 1024]
        logits = self.classifier(fused)                     # [batch, 2]

        loss = None
        if labels is not None:
            loss = self.loss_fn(logits, labels)

        return {'loss': loss, 'logits': logits}


def compute_metrics(eval_pred):
    logits, labels = eval_pred
    probs = torch.softmax(torch.tensor(logits), dim=-1)[:, 1].numpy()
    preds = np.argmax(logits, axis=-1)
    return {
        'accuracy': accuracy_score(labels, preds),
        'f1': f1_score(labels, preds),
        'roc_auc': roc_auc_score(labels, probs),
        'avg_precision': average_precision_score(labels, probs),
    }

print('Model class and metrics function defined')
print(f'Architecture: RoBERTa [CLS](768) + TF-IDF proj(256) → fused(1024) → classifier → 2')
print(f'Loss: FocalLoss(alpha={FOCAL_ALPHA}, gamma={FOCAL_GAMMA}, label_smoothing={LABEL_SMOOTHING})')
print(f'Regularization: dropout={DROPOUT}, freeze=all except last 4 layers')

# %%
# ═══════════════════════════════════════════════════════════════════
#  5-FOLD STRATIFIED CROSS-VALIDATION
# ═══════════════════════════════════════════════════════════════════
# Each fold:
#   1. Split REAL data into train/val (synthetic always in train)
#   2. Fit TF-IDF on training text only (no leakage)
#   3. SMOTE oversample fraud in TF-IDF feature space
#   4. Train model with early stopping on val F1
#   5. Collect val predictions for aggregated metrics
# ═══════════════════════════════════════════════════════════════════

skf = StratifiedKFold(n_splits=N_FOLDS, shuffle=True, random_state=SEED)

fold_metrics = []
all_val_pids = []
all_val_labels = []
all_val_probs = []
all_val_preds = []

for fold_idx, (train_indices, val_indices) in enumerate(skf.split(real_df, real_df['fraud_label']), 1):
    print(f'\n{"="*60}')
    print(f'  FOLD {fold_idx}/{N_FOLDS}')
    print(f'{"="*60}')

    # Split real data
    fold_train_real = real_df.iloc[train_indices].reset_index(drop=True)
    fold_val = real_df.iloc[val_indices].reset_index(drop=True)

    # Add ALL synthetic data to training (never to validation)
    fold_train = pd.concat([fold_train_real, synth_df_combined], ignore_index=True)

    n_train_fraud = fold_train['fraud_label'].sum()
    n_val_fraud = fold_val['fraud_label'].sum()
    print(f'Train: {len(fold_train)} ({n_train_fraud} fraud, {100*n_train_fraud/len(fold_train):.1f}%)')
    print(f'Val:   {len(fold_val)} ({n_val_fraud} fraud, {100*n_val_fraud/len(fold_val):.1f}%)')

    # Fit TF-IDF on this fold's training data only
    fold_tfidf = TfidfVectorizer(
        max_features=TFIDF_MAX_FEATURES,
        ngram_range=TFIDF_NGRAM_RANGE,
        sublinear_tf=True,
        strip_accents='unicode',
    )
    tfidf_train = fold_tfidf.fit_transform(fold_train['text']).toarray().astype(np.float32)
    tfidf_val   = fold_tfidf.transform(fold_val['text']).toarray().astype(np.float32)
    tfidf_dim   = tfidf_train.shape[1]

    # ── SMOTE oversampling in TF-IDF feature space ──────────────────
    train_texts = fold_train['text'].tolist()
    train_labels = fold_train['fraud_label'].values

    if SMOTE_ENABLED:
        n_fraud_before = int(train_labels.sum())
        n_legit = int((train_labels == 0).sum())
        smote_target = int(n_legit * SMOTE_RATIO)
        n_to_generate = max(0, smote_target - n_fraud_before)

        if n_to_generate > 0:
            k = min(SMOTE_K_NEIGHBORS, n_fraud_before - 1)
            smote = SMOTE(
                sampling_strategy={1: smote_target},
                k_neighbors=k,
                random_state=SEED + fold_idx,
            )
            tfidf_resampled, labels_resampled = smote.fit_resample(tfidf_train, train_labels)

            # SMOTE appends synthetic samples at the end
            n_original = len(train_labels)
            n_synthetic = len(labels_resampled) - n_original
            synthetic_tfidf = tfidf_resampled[n_original:]

            # Map each SMOTE sample → nearest real fraud text (for RoBERTa)
            fraud_mask = train_labels == 1
            fraud_tfidf = tfidf_train[fraud_mask]
            fraud_texts = [train_texts[i] for i in range(len(train_texts)) if fraud_mask[i]]

            nn_model = NearestNeighbors(n_neighbors=1, metric='cosine')
            nn_model.fit(fraud_tfidf)
            _, nn_idx = nn_model.kneighbors(synthetic_tfidf)
            smote_texts = [fraud_texts[j] for j in nn_idx.flatten()]

            # Merge originals + SMOTE synthetics
            train_texts = train_texts + smote_texts
            train_labels = labels_resampled
            tfidf_train = tfidf_resampled

            print(f'  SMOTE: +{n_synthetic} fraud samples in TF-IDF space '
                  f'(fraud {n_fraud_before}→{int(train_labels.sum())}, '
                  f'total {n_original}→{len(train_labels)})')
        else:
            print(f'  SMOTE: skipped — fraud already ≥ target ({n_fraud_before} ≥ {smote_target})')
    # ────────────────────────────────────────────────────────────────

    # Create datasets
    train_dataset = FraudTextDataset(
        train_texts, train_labels.tolist(),
        tfidf_train, training=True,
    )
    val_dataset = FraudTextDataset(
        fold_val['text'].tolist(), fold_val['fraud_label'].tolist(),
        tfidf_val, training=False,
    )

    # Fresh model for each fold
    fold_model = RoBERTaTfidfFraudModel(MODEL_NAME, tfidf_dim=tfidf_dim)
    fold_model = fold_model.to(device)

    fold_output_dir = OUTPUT_DIR / f'fold_{fold_idx}'
    training_args = TrainingArguments(
        output_dir=str(fold_output_dir),
        num_train_epochs=EPOCHS,
        per_device_train_batch_size=BATCH_SIZE,
        per_device_eval_batch_size=BATCH_SIZE * 2,
        gradient_accumulation_steps=GRAD_ACCUM,
        learning_rate=LR,
        weight_decay=0.01,
        warmup_ratio=0.1,
        fp16=torch.cuda.is_available(),
        eval_strategy='epoch',
        save_strategy='epoch',
        logging_steps=50,
        load_best_model_at_end=True,
        metric_for_best_model='f1',
        greater_is_better=True,
        save_total_limit=2,
        seed=SEED,
        report_to='none',
    )

    trainer = Trainer(
        model=fold_model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=val_dataset,
        compute_metrics=compute_metrics,
        callbacks=[EarlyStoppingCallback(early_stopping_patience=2)],
    )

    # Train this fold
    trainer.train()

    # Evaluate on validation fold
    preds_output = trainer.predict(val_dataset)
    logits = preds_output.predictions
    probs = torch.softmax(torch.tensor(logits), dim=-1)[:, 1].numpy()
    preds = np.argmax(logits, axis=-1)
    labels = fold_val['fraud_label'].values

    fold_acc = accuracy_score(labels, preds)
    fold_f1  = f1_score(labels, preds)
    fold_roc = roc_auc_score(labels, probs)
    fold_ap  = average_precision_score(labels, probs)

    fold_metrics.append({
        'fold': fold_idx,
        'accuracy': fold_acc,
        'f1': fold_f1,
        'roc_auc': fold_roc,
        'avg_precision': fold_ap,
    })

    # Collect predictions for aggregated report
    all_val_pids.extend(fold_val['product_id'].values)
    all_val_labels.extend(labels)
    all_val_probs.extend(probs)
    all_val_preds.extend(preds)

    print(f'\nFold {fold_idx} results:')
    print(f'  Accuracy: {fold_acc:.4f}  F1: {fold_f1:.4f}  ROC-AUC: {fold_roc:.4f}  AP: {fold_ap:.4f}')

    # Clean up GPU memory between folds
    del fold_model, trainer, train_dataset, val_dataset
    torch.cuda.empty_cache() if device.type == 'cuda' else None

print(f'\n{"="*60}')
print(f'  ALL FOLDS COMPLETE')
print(f'{"="*60}')

# %%
# ═══════════════════════════════════════════════════════════════════
#  AGGREGATED CROSS-VALIDATION RESULTS
# ═══════════════════════════════════════════════════════════════════

metrics_df = pd.DataFrame(fold_metrics)
print('Per-fold metrics:')
print(metrics_df.to_string(index=False, float_format='{:.4f}'.format))

print(f'\n{"="*60}')
print(f'  {N_FOLDS}-FOLD CV SUMMARY (mean ± std)')
print(f'{"="*60}')
for metric in ['accuracy', 'f1', 'roc_auc', 'avg_precision']:
    mean_val = metrics_df[metric].mean()
    std_val  = metrics_df[metric].std()
    print(f'{metric:20s}: {mean_val:.4f} ± {std_val:.4f}')

# Aggregated predictions (every real sample validated exactly once)
y_true_all = np.array(all_val_labels)
y_pred_all = np.array(all_val_preds)
y_prob_all = np.array(all_val_probs)

print(f'\nAggregated results (all {len(y_true_all)} real samples):')
print(f'  Accuracy: {accuracy_score(y_true_all, y_pred_all):.4f}')
print(f'  F1:       {f1_score(y_true_all, y_pred_all):.4f}')
print(f'  ROC-AUC:  {roc_auc_score(y_true_all, y_prob_all):.4f}')
print(f'  AP:       {average_precision_score(y_true_all, y_prob_all):.4f}')

print(f'\nClassification Report (aggregated):')
print(classification_report(y_true_all, y_pred_all, target_names=['Not Fraud', 'Fraud']))
print('Confusion Matrix (aggregated):')
print(confusion_matrix(y_true_all, y_pred_all))

# %%
# ═══════════════════════════════════════════════════════════════════
#  TRAIN FINAL MODEL ON ALL DATA (for deployment)
# ═══════════════════════════════════════════════════════════════════
# Now that we have reliable CV metrics, train the final model on ALL
# data (real + synthetic) for maximum performance at inference time.

print('Training final model on ALL data for deployment ...\n')

# Fit TF-IDF on ALL combined text
final_tfidf = TfidfVectorizer(
    max_features=TFIDF_MAX_FEATURES,
    ngram_range=TFIDF_NGRAM_RANGE,
    sublinear_tf=True,
    strip_accents='unicode',
)
tfidf_all = final_tfidf.fit_transform(df['text']).toarray().astype(np.float32)
TFIDF_DIM = tfidf_all.shape[1]

# Full dataset (training only — no eval set for final model)
full_dataset = FraudTextDataset(
    df['text'].tolist(), df['fraud_label'].tolist(),
    tfidf_all, training=True,
)

# Fresh model
final_model = RoBERTaTfidfFraudModel(MODEL_NAME, tfidf_dim=TFIDF_DIM)
final_model = final_model.to(device)

trainable = sum(p.numel() for p in final_model.parameters() if p.requires_grad)
total     = sum(p.numel() for p in final_model.parameters())
print(f'Trainable params: {trainable:,} / {total:,} ({100*trainable/total:.1f}%)')

# Use average best epoch from CV folds as the epoch count
avg_best_epoch = max(3, int(np.mean([m['fold'] for m in fold_metrics])))  # at least 3
# Actually use the median number of training epochs from CV
# Since we don't track exact stopping epoch, use EPOCHS with no early stopping
# but cap at a reasonable number. The CV results tell us the model generalizes.
final_epochs = min(EPOCHS, 8)  # conservative — CV already validated

final_training_args = TrainingArguments(
    output_dir=str(OUTPUT_DIR / 'final'),
    num_train_epochs=final_epochs,
    per_device_train_batch_size=BATCH_SIZE,
    per_device_eval_batch_size=BATCH_SIZE * 2,
    gradient_accumulation_steps=GRAD_ACCUM,
    learning_rate=LR,
    weight_decay=0.01,
    warmup_ratio=0.1,
    fp16=torch.cuda.is_available(),
    eval_strategy='no',      # no eval set — training on everything
    save_strategy='epoch',
    logging_steps=50,
    save_total_limit=1,
    seed=SEED,
    report_to='none',
)

final_trainer = Trainer(
    model=final_model,
    args=final_training_args,
    train_dataset=full_dataset,
)

print(f'Training final model for {final_epochs} epochs on {len(full_dataset)} samples ...')
final_trainer.train()
print('\nFinal model training complete.')

# %%
# Export cross-validated predictions for ensemble
text_preds_df = pd.DataFrame({
    'product_id': all_val_pids,
    'fraud_label': y_true_all,
    'text_fraud_proba': y_prob_all,
    'text_pred': y_pred_all,
})
text_preds_df.to_csv('text_test_predictions.csv', index=False)
print(f'Saved text_test_predictions.csv  ({len(text_preds_df)} rows — all real samples, cross-validated)')
print(text_preds_df.head())

# Download for local ensemble
if IN_COLAB:
    files.download('text_test_predictions.csv')

# %%
# Save final model, tokenizer, and TF-IDF vectorizer
save_path = OUTPUT_DIR / 'best_model'
save_path.mkdir(parents=True, exist_ok=True)

# Save full hybrid model state dict
torch.save(final_model.state_dict(), save_path / 'hybrid_roberta_tfidf.pth')

# Save tokenizer (needed for RoBERTa inference)
tokenizer.save_pretrained(str(save_path))

# Save TF-IDF vectorizer (needed to transform new text at inference)
joblib.dump(final_tfidf, save_path / 'tfidf_vectorizer.joblib')

print(f'Saved to: {save_path.resolve()}')
print(f'  - hybrid_roberta_tfidf.pth  (model weights)')
print(f'  - tokenizer files           (RoBERTa tokenizer)')
print(f'  - tfidf_vectorizer.joblib   (TF-IDF vectorizer)')

# Optional: download in Colab
if IN_COLAB:
    import shutil
    shutil.make_archive('roberta_tfidf_model', 'zip', save_path)
    files.download('roberta_tfidf_model.zip')
